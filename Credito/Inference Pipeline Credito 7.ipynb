# %% [markdown]
# # Inference Pipeline with Scikit-learn and Linear Learner
# Typically a Machine Learning (ML) process consists of few steps: data gathering with various ETL jobs, pre-processing the data, featurizing the dataset by incorporating standard techniques or prior knowledge, and finally training an ML model using an algorithm.
# In many cases, when the trained model is used for processing real time or batch prediction requests, the model receives data in a format which needs to pre-processed (e.g. featurized) before it can be passed to the algorithm. In the following notebook, we will demonstrate how you can build your ML Pipeline leveraging the Sagemaker Scikit-learn container and SageMaker Linear Learner algorithm & after the model is trained, deploy the Pipeline (Data preprocessing and Lineara Learner) as an Inference Pipeline behind a single Endpoint for real time inference and for batch inferences using Amazon SageMaker Batch Transform.
#
# We will demonstrate this using the Abalone Dataset to guess the age of Abalone with physical features. The dataset is available from [UCI Machine Learning](https://archive.ics.uci.edu/ml/datasets/abalone); the aim for this task is to determine age of an Abalone (a kind of shellfish) from its physical measurements. We'll use Sagemaker's Scikit-learn container to featurize the dataset so that it can be used for training with Linear Learner.
#
# ### Table of contents
# * [Preprocessing data and training the model](#training)
#  * [Upload the data for training](#upload_data)
#  * [Create a Scikit-learn script to train with](#create_sklearn_script)
#  * [Create SageMaker Scikit Estimator](#create_sklearn_estimator)
#  * [Batch transform our training data](#preprocess_train_data)
#  * [Fit a LinearLearner Model with the preprocessed data](#training_model)
# * [Inference Pipeline with Scikit preprocessor and Linear Learner](#inference_pipeline)
#  * [Set up the inference pipeline](#pipeline_setup)
#  * [Make a request to our pipeline endpoint](#pipeline_inference_request)
#  * [Delete Endpoint](#delete_endpoint)

# %% [markdown]
# Let's first create our Sagemaker session and role, and create a S3 prefix to use for the notebook example.

# %%
#!pip -q install sagemaker=2.0.0

# %%
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# S3 prefix
#bucket = sagemaker_session.default_bucket()
bucket = 'credito-poc'
prefix = 'test1'
# Out:
# Couldn't call 'get_role' to get Role ARN from role name rubens.mau to get Role path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a8da73f02ba2> in <module>()
#       5
#       6 # Get a SageMaker-compatible role used by this Notebook Instance.
# ----> 7 role = get_execution_role()
#       8
#       9 # S3 prefix
#
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/session.py in get_execution_role(sagemaker_session)
#    4129         "SageMaker execution role"
#    4130     )
# -> 4131     raise ValueError(message.format(arn))
#    4132
#    4133
#
# ValueError: The current AWS identity is not a role: arn:aws:iam::785315722499:user/rubens.mau, therefore it cannot be used as a SageMaker execution role

# %%
import boto3
iam = boto3.client('iam')
role = iam.get_role(RoleName='sagemaker-mau')['Role']['Arn']
role
# Out:
# 'arn:aws:iam::785315722499:role/sagemaker-mau'

# %%
sagemaker_session = sagemaker.Session()

# %% [markdown]
# # Preprocessing data and training the model <a class="anchor" id="training"></a>
# ## Downloading dataset <a class="anchor" id="download_data"></a>
# SageMaker team has downloaded the dataset from UCI and uploaded to one of the S3 buckets in our account.

# %%
#!wget --directory-prefix=./abalone_data https://s3-us-west-2.amazonaws.com/sparkml-mleap/data/abalone/abalone.csv

# %% [markdown]
# ## Upload the data for training <a class="anchor" id="upload_data"></a>
#
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. We can use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
bucket = 'credito-poc'
prefix = 'test1'

WORK_DIRECTORY = 'credito_data'

train_input = sagemaker_session.upload_data(
    path='{}/{}'.format(WORK_DIRECTORY, 'credito_limpo.csv'), 
    bucket=bucket,
    key_prefix='{}/{}'.format(prefix, 'train'))

# %%
train_input
# Out:
# 's3://credito-poc/test1/train/credito_limpo.csv'

# %% [markdown]
# bggg## Create a Scikit-learn script to train with <a class="anchor" id="create_sklearn_script"></a>
# To run Scikit-learn on Sagemaker `SKLearn` Estimator with a script as an entry point. The training script is very similar to a training script you might run outside of SageMaker, but you can access useful properties about the training environment through various environment variables, such as:
#
# * SM_MODEL_DIR: A string representing the path to the directory to write model artifacts to. These artifacts are uploaded to S3 for model hosting.
# * SM_OUTPUT_DIR: A string representing the filesystem path to write output artifacts to. Output artifacts may include checkpoints, graphs, and other files to save, not including model artifacts. These artifacts are compressed and uploaded to S3 to the same S3 prefix as the model artifacts.
#
# Supposing two input channels, 'train' and 'test', were used in the call to the Chainer estimator's fit() method, the following will be set, following the format SM_CHANNEL_[channel_name]:
#
# * SM_CHANNEL_TRAIN: A string representing the path to the directory containing data in the 'train' channel
# * SM_CHANNEL_TEST: Same as above, but for the 'test' channel.
#
# A typical training script loads data from the input channels, configures training with hyperparameters, trains a model, and saves a model to model_dir so that it can be hosted later. Hyperparameters are passed to your script as arguments and can be retrieved with an argparse.ArgumentParser instance. For example, the script run by this notebook
#
# ###  script usado é credito_featurizer.py

# %% [markdown]
# ## Create SageMaker Scikit Estimator <a class="anchor" id="create_sklearn_estimator"></a>
#
# To run our Scikit-learn training script on SageMaker, we construct a `sagemaker.sklearn.estimator.sklearn` estimator, which accepts several constructor arguments:
#
# * __entry_point__: The path to the Python script SageMaker runs for training and prediction.
# * __role__: Role ARN
# * __framework_version__: Scikit-learn version you want to use for executing your model training code.
# * __train_instance_type__ *(optional)*: The type of SageMaker instances for training. __Note__: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * __sagemaker_session__ *(optional)*: The session used to train on Sagemaker.
#
# To see the code for the SKLearn Estimator, see here: https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/sklearn

# %%
#!python credito_featurizer.py --train credito_data  --model .  --output-data-dir  .

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
script_path = 'credito_featurizer2.py'

sklearn_preprocessor = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    #train_instance_type="ml.c4.xlarge",
    instance_type = "ml.m5.large",
    sagemaker_session=sagemaker_session)

# %%
sklearn_preprocessor.fit({'train': train_input})
# Out:
# 2021-03-12 19:11:32 Starting - Starting the training job...
# 2021-03-12 19:11:56 Starting - Launching requested ML instancesProfilerReport-1615576292: InProgress
# ......
# 2021-03-12 19:12:56 Starting - Preparing the instances for training...
# 2021-03-12 19:13:25 Downloading - Downloading input data...
# 2021-03-12 19:13:56 Training - Downloading the training image..
# 2021-03-12 19:14:29 Uploading - Uploading generated training model
# 2021-03-12 19:14:29 Completed - Training job completed
# 2021-03-12 19:14:16,823 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-03-12 19:14:16,825 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-12 19:14:16,834 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-03-12 19:14:17,113 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-12 19:14:17,124 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-12 19:14:17,134 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-12 19:14:17,143 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-03-12-19-11-32-521",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-03-12-19-11-32-521/source/sourcedir.tar.gz",
#     "module_name": "credito_featurizer2",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "credito_featurizer2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=credito_featurizer2.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=credito_featurizer2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-03-12-19-11-32-521/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-03-12-19-11-32-521","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-03-12-19-11-32-521/source/sourcedir.tar.gz","module_name":"credito_featurizer2","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"credito_featurizer2.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python credito_featurizer2.py
#
#
# saved model!
# 2021-03-12 19:14:18,585 sagemaker-containers INFO     Reporting training SUCCESS
# Training seconds: 64
# Billable seconds: 64

# %% [markdown]
# ## Batch transform our training data <a class="anchor" id="preprocess_train_data"></a>
# Now that our proprocessor is properly fitted, let's go ahead and preprocess our training data. Let's use batch transform to directly preprocess the raw data and store right back into s3.

# %%
# Define a SKLearn Transformer from the trained SKLearn Estimator
transformer = sklearn_preprocessor.transformer(
    instance_count=1, 
    instance_type= 'ml.p3.2xlarge',
    assemble_with = 'Line',
    accept = 'text/csv')

# %%
train_input
# Out:
# 's3://credito-poc/test1/train/credito_limpo.csv'

# %%
# Preprocess training input
transformer.transform(train_input, content_type="text/csv")
print("Waiting for transform job: " + transformer.latest_transform_job.job_name)
# Out:
# ..............................
# 2021-03-12 19:20:39,555 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021/03/12 19:20:39 [crit] 17#17: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:39 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021-03-12 19:20:39,679 INFO - sagemaker-containers - Module credito_featurizer2 does not provide a setup.py.
# Generating setup.py
# 2021-03-12 19:20:39,680 INFO - sagemaker-containers - Generating setup.cfg
# 2021-03-12 19:20:39,680 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-03-12 19:20:39,680 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# 2021/03/12 19:20:39 [crit] 17#17: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:39 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:39 [crit] 17#17: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:39 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:39 [crit] 17#17: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:39 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:40 [crit] 17#17: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Processing /opt/ml/code
# 2021/03/12 19:20:40 [crit] 17#17: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:40 [crit] 17#17: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Building wheels for collected packages: credito-featurizer2
#   Building wheel for credito-featurizer2 (setup.py): started
# 2021/03/12 19:20:40 [crit] 17#17: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:40 [crit] 17#17: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:40 [crit] 17#17: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for credito-featurizer2 (setup.py): finished with status 'done'
#   Created wheel for credito-featurizer2: filename=credito_featurizer2-1.0.0-py2.py3-none-any.whl size=8344 sha256=c037ea65d74117f4328f94fad00b2efebb31983c2cce88add6f7c557fa2d24c5
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-u7lnwoku/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built credito-featurizer2
# 2021/03/12 19:20:40 [crit] 17#17: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:40 [crit] 17#17: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:40 [crit] 17#17: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Installing collected packages: credito-featurizer2
# Successfully installed credito-featurizer2-1.0.0
# 2021/03/12 19:20:40 [crit] 17#17: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:40 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *33 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *35 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *37 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *39 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *41 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/03/12 19:20:41 [crit] 17#17: *43 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [12/Mar/2021:19:20:41 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-03-12 19:20:41 +0000] [48] [INFO] Starting gunicorn 20.0.4
# [2021-03-12 19:20:41 +0000] [48] [INFO] Listening at: unix:/tmp/gunicorn.sock (48)
# [2021-03-12 19:20:41 +0000] [48] [INFO] Using worker: gevent
# [2021-03-12 19:20:41 +0000] [51] [INFO] Booting worker with pid: 51
# [2021-03-12 19:20:41 +0000] [52] [INFO] Booting worker with pid: 52
# [2021-03-12 19:20:41 +0000] [60] [INFO] Booting worker with pid: 60
# [2021-03-12 19:20:42 +0000] [61] [INFO] Booting worker with pid: 61
# [2021-03-12 19:20:42 +0000] [69] [INFO] Booting worker with pid: 69
# [2021-03-12 19:20:42 +0000] [70] [INFO] Booting worker with pid: 70
# [2021-03-12 19:20:42 +0000] [71] [INFO] Booting worker with pid: 71
# [2021-03-12 19:20:42 +0000] [79] [INFO] Booting worker with pid: 79
# 169.254.255.130 - - [12/Mar/2021:19:20:43 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [12/Mar/2021:19:20:44 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [12/Mar/2021:19:20:44 +0000] "POST /invocations HTTP/1.1" 200 362843 "-" "Go-http-client/1.1"
# 2021-03-12T19:20:44.088:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Waiting for transform job: sagemaker-scikit-learn-2021-03-12-19-15-46-774

# %%
#transformer.wait()
preprocessed_train = transformer.output_path

# %% [markdown]
# ## Fit a LinearLearner Model with the preprocessed data <a class="anchor" id="training_model"></a>
# Let's take the preprocessed training data and fit a LinearLearner Model. Sagemaker provides prebuilt algorithm containers that can be used with the Python SDK. The previous Scikit-learn job preprocessed the raw Titanic dataset into labeled, useable data that we can now use to fit a binary classifier Linear Learner model.
#
# For more on Linear Learner see: https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html

# %%
import boto3
from sagemaker.image_uris import retrieve
ll_image = retrieve('linear-learner', boto3.Session().region_name)

# %%
preprocessed_train
# Out:
# 's3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-03-12-19-15-46-774'

# %%
# import boto3
# import io
# s3 = boto3.client('s3')
# obj = s3.get_object(Bucket='sagemaker-us-east-2-785315722499', Key='sagemaker-scikit-learn-2021-02-18-21-28-39-475')
# df = pd.read_csv(io.BytesIO(obj['Body'].read()))

# %%
s3_ll_output_key_prefix = "ll_training_output"
s3_ll_output_location = 's3://{}/{}/{}/{}'.format(bucket, prefix, s3_ll_output_key_prefix, 'll_model')

ll_estimator = sagemaker.estimator.Estimator(
    ll_image,
    role, 
    instance_count=1, 
    instance_type='ml.m4.2xlarge',
    volume_size = 20,
    max_run = 3600,
    input_mode= 'File',
    output_path=s3_ll_output_location,
    sagemaker_session=sagemaker_session)

### incluir features depois do preprocessing - sem icluir a variavel y
### nosso caso no bucket preprocessed_train, o arquivo .out tem 47 colunas - sendo a primeira coluna y
ll_estimator.set_hyperparameters(feature_dim=46, predictor_type='binary_classifier', mini_batch_size=32)

ll_train_data = sagemaker.inputs.TrainingInput(
    preprocessed_train, 
    distribution='FullyReplicated',
    content_type='text/csv', 
    s3_data_type='S3Prefix')

data_channels = {'train': ll_train_data}
ll_estimator.fit(inputs=data_channels, logs=True)
# Out:
# 2021-03-12 19:21:32 Starting - Starting the training job...
# 2021-03-12 19:21:38 Starting - Launching requested ML instancesProfilerReport-1615576892: InProgress
# ......
# 2021-03-12 19:22:43 Starting - Preparing the instances for training......
# 2021-03-12 19:24:03 Downloading - Downloading input data
# 2021-03-12 19:24:03 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/12/2021 19:24:15 INFO 140064612235072] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/12/2021 19:24:15 INFO 140064612235072] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'46', u'mini_batch_size': u'32', u'predictor_type': u'binary_classifier'}
# [03/12/2021 19:24:15 INFO 140064612235072] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'46', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'32', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/12/2021 19:24:15 WARNING 140064612235072] Loggers have already been setup.
# Process 1 is a worker.
# [03/12/2021 19:24:15 INFO 140064612235072] Using default worker.
# [03/12/2021 19:24:16 INFO 140064612235072] Checkpoint loading and saving are disabled.
# [03/12/2021 19:24:16 INFO 140064612235072] Create Store: local
# [03/12/2021 19:24:16 INFO 140064612235072] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f62f95a59d0>
# [03/12/2021 19:24:16 INFO 140064612235072] Scaling model computed with parameters:
#  {'stdev_weight':
# [1.003851   1.0038021  0.9853885  1.0011839  0.9974451  1.0032812
#  1.0009227  0.9477312  0.99942875 0.976335   1.0012287  0.14726025
#  0.35124502 0.4822458  0.40120456 0.24387449 0.44193253 0.44712174
#  0.488668   0.24387455 0.4893132  0.30372706 0.21458279 0.38622287
#  0.48973262 0.48973262 0.48589018 0.4557522  0.28286043 0.35726893
#  0.47080702 0.45106807 0.42329106 0.4226556  0.3050407  0.21877557
#  0.10931806 0.4491174  0.29427022 0.38622287 0.10471748 0.14726026
#  0.09481702 0.38455647 0.3063455  0.45154878]
# <NDArray 46 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 1
# [03/12/2021 19:24:32 INFO 140064612235072] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.466345805168
# [03/12/2021 19:24:32 INFO 140064612235072] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.783
# [03/12/2021 19:24:32 INFO 140064612235072] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.578640776699
# [03/12/2021 19:24:32 INFO 140064612235072] #quality_metric: host=algo-1, train precision <score>=0.693023255814
# [03/12/2021 19:24:32 INFO 140064612235072] #quality_metric: host=algo-1, train recall <score>=0.496666666667
# [03/12/2021 19:24:32 INFO 140064612235072] #quality_metric: host=algo-1, train roc_auc_score <score>=0.817923809524
# [03/12/2021 19:24:32 INFO 140064612235072] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [03/12/2021 19:24:32 INFO 140064612235072] Saved checkpoint to "/tmp/tmpfmGHM9/mx-mod-0000.params"
# [03/12/2021 19:24:32 INFO 140064612235072] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 16950.417041778564, "sum": 16950.417041778564, "min": 16950.417041778564}, "finalize.time": {"count": 1, "max": 458.0659866333008, "sum": 458.0659866333008, "min": 458.0659866333008}, "initialize.time": {"count": 1, "max": 359.7080707550049, "sum": 359.7080707550049, "min": 359.7080707550049}, "check_early_stopping.time": {"count": 15, "max": 0.9751319885253906, "sum": 10.456323623657227, "min": 0.1881122589111328}, "setuptime": {"count": 1, "max": 27.519941329956055, "sum": 27.519941329956055, "min": 27.519941329956055}, "update.time": {"count": 15, "max": 1186.5370273590088, "sum": 15855.592489242554, "min": 1009.5298290252686}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1615577072.87698, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1615577056.147319}
# 2021-03-12 19:25:04 Uploading - Uploading generated training model
# 2021-03-12 19:25:04 Completed - Training job completed
# Training seconds: 67
# Billable seconds: 67

# %% [markdown]
# # Serial Inference Pipeline with Scikit preprocessor and Linear Learner <a class="anchor" id="serial_inference"></a>

# %% [markdown]
# ## Set up the inference pipeline <a class="anchor" id="pipeline_setup"></a>
# Setting up a Machine Learning pipeline can be done with the Pipeline Model. This sets up a list of models in a single endpoint; in this example, we configure our pipeline model with the fitted Scikit-learn inference model and the fitted Linear Learner model. Deploying the model follows the same ```deploy``` pattern in the SDK.

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = 'inference-pipeline-' + timestamp_prefix
endpoint_name = 'inference-pipeline-ep-' + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, 
    role=role, 
    models=[
        scikit_learn_inferencee_model ,
        linear_learner_model])

sm_model.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge', endpoint_name=endpoint_name)
# Out:
# ---------------!

# %%
endpoint_name
# Out:
# 'inference-pipeline-ep-2021-03-12-19-25-15'

# %% [markdown]
# ## DEPLOY ENDPOINT FROM S3   ---- NAO FUNCIONA !!!
# Neste caso o modelo ja foi produzido e uma cópia encontra-se em S3
# Para economia de custos, devemos baixar o endpoint sempre que nao estáem uso, e levantar com esta rotina

# %%
from sagemaker.sklearn.model import SKLearnModel
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()
# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()
script_path = 'credito_featurizer.py'

# %%
###  retrieve the preprocessing model
modelo = 's3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-02-19-11-27-20-768/output/model.tar.gz'
FRAMEWORK_VERSION = "0.23-1"    
    
scikit_learn_inferencee_model = SKLearnModel(model_data=modelo,
                             role=role,
                             entry_point=script_path,
                             sagemaker_session=sagemaker_session,
                             framework_version=FRAMEWORK_VERSION)




#mau_model.deploy(instance_type="ml.c4.xlarge", initial_instance_count=1,endpoint_name='credito1')

# %%
# retrieve the linear model
modelo = 's3://credito-poc/test1/ll_training_output/ll_model/linear-learner-2021-02-19-11-41-06-019/output/model.tar.gz'
FRAMEWORK_VERSION = "0.23-1"    
    
linear_learner_model =     SKLearnModel(model_data=modelo,
                             role=role,
                             entry_point=script_path,
                             sagemaker_session=sagemaker_session,
                             framework_version=FRAMEWORK_VERSION)

# %%
# make pipeline fromm the two previous models

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = 'inference-pipeline-' + timestamp_prefix
endpoint_name = 'inference-pipeline-ep-' + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, 
    role=role, 
    models=[
        scikit_learn_inferencee_model ,
        linear_learner_model])

sm_model.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge', endpoint_name=endpoint_name)
# Out:
# ----------------!

# %% [markdown]
# ## Make a request to our pipeline endpoint <a class="anchor" id="pipeline_inference_request"></a>
#
# Here we just grab the first line from the test data (you'll notice that the inference python script is very particular about the ordering of the inference request data). The ```ContentType``` field configures the first container, while the ```Accept``` field configures the last container. You can also specify each container's ```Accept``` and ```ContentType``` values using environment variables.
#
# We make our request with the payload in ```'text/csv'``` format, since that is what our script currently supports. If other formats need to be supported, this would have to be added to the ```output_fn()``` method in our entry point. Note that we set the ```Accept``` to ```application/json```, since Linear Learner does not support ```text/csv``` ```Accept```. The prediction output in this case is trying to guess the number of rings the abalone specimen would have given its other physical features; the actual number of rings is 10.

# %%
print(endpoint_name)
# endpoint_name = inference-pipeline-ep-2021-02-19-11-47-0
# Out:
# inference-pipeline-ep-2021-03-12-19-25-15

# %%
endpoint_name = 'inference-pipeline-ep-2021-02-19-15-09-17'
endpoint_name = 'inference-pipeline-ep-2021-02-19-11-47-06'

# %%
###  Prediction using Python SDK

import sagemaker
from sagemaker import get_execution_role

from sagemaker.predictor import Predictor
#from sagemaker.predictor import predict
from sagemaker.serializers import CSVSerializer
sagemaker_session = sagemaker.Session()
#endpoint_name = 'inference-pipeline-ep-2021-02-15-13-10-44'
payload = '0,0,0,operario,sem conta,2,1,1,muito_alta,2,1500,Nao,2,6,muito pobre,imovel,carro novo,proprio,2'

predictor = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=CSVSerializer())

print(predictor.predict(payload))
# Out:
# b'{"predictions": [{"score": 0.025737501680850983, "predicted_label": 0}]}'

# %%
##  Prediction using boto3 - like in Lambda
import json
runtime = boto3.client('runtime.sagemaker')

# Send CSV text via InvokeEndpoint API
response = runtime.invoke_endpoint(EndpointName=endpoint_name, ContentType='text/csv', Body=payload)
# Unpack response
result = json.loads(response['Body'].read().decode())
result
# Out:
# {'predictions': [{'score': 0.025737501680850983, 'predicted_label': 0}]}

# %% [markdown]
# ## Delete Endpoint <a class="anchor" id="delete_endpoint"></a>
# Once we are finished with the endpoint, we clean up the resources!

# %%
sm_client = sagemaker_session.boto_session.client('sagemaker')
sm_client.delete_endpoint(EndpointName=endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '86917b6c-ef77-43d6-9264-d1a2d0f07947',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '86917b6c-ef77-43d6-9264-d1a2d0f07947',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Fri, 12 Mar 2021 19:37:51 GMT'},
#   'RetryAttempts': 0}}

# %%
str = "1234,"
str[:-1]
# Out:
# '1234'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-d3ee727be0a5> in <module>
# ----> 1 listToStr = ' '.join(map(str, p),',')
#       2 listToStr
#
# TypeError: join() takes exactly one argument (2 given)

# %%
str1 = "" 
for elem in p:
    str1 = str1 + str(elem) + ','
print(str1)
# Out:
# 0,0,0,operario,sem conta,2,1,1,muito_alta,2,1500,Nao,2,6,muito pobre,imovel,carro novo,proprio,2,
