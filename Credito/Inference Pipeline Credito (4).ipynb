# %% [markdown]
# # Inference Pipeline with Scikit-learn and Linear Learner
# Typically a Machine Learning (ML) process consists of few steps: data gathering with various ETL jobs, pre-processing the data, featurizing the dataset by incorporating standard techniques or prior knowledge, and finally training an ML model using an algorithm.
# In many cases, when the trained model is used for processing real time or batch prediction requests, the model receives data in a format which needs to pre-processed (e.g. featurized) before it can be passed to the algorithm. In the following notebook, we will demonstrate how you can build your ML Pipeline leveraging the Sagemaker Scikit-learn container and SageMaker Linear Learner algorithm & after the model is trained, deploy the Pipeline (Data preprocessing and Lineara Learner) as an Inference Pipeline behind a single Endpoint for real time inference and for batch inferences using Amazon SageMaker Batch Transform.
#
# We will demonstrate this using the Abalone Dataset to guess the age of Abalone with physical features. The dataset is available from [UCI Machine Learning](https://archive.ics.uci.edu/ml/datasets/abalone); the aim for this task is to determine age of an Abalone (a kind of shellfish) from its physical measurements. We'll use Sagemaker's Scikit-learn container to featurize the dataset so that it can be used for training with Linear Learner.
#
# ### Table of contents
# * [Preprocessing data and training the model](#training)
#  * [Upload the data for training](#upload_data)
#  * [Create a Scikit-learn script to train with](#create_sklearn_script)
#  * [Create SageMaker Scikit Estimator](#create_sklearn_estimator)
#  * [Batch transform our training data](#preprocess_train_data)
#  * [Fit a LinearLearner Model with the preprocessed data](#training_model)
# * [Inference Pipeline with Scikit preprocessor and Linear Learner](#inference_pipeline)
#  * [Set up the inference pipeline](#pipeline_setup)
#  * [Make a request to our pipeline endpoint](#pipeline_inference_request)
#  * [Delete Endpoint](#delete_endpoint)

# %% [markdown]
# Let's first create our Sagemaker session and role, and create a S3 prefix to use for the notebook example.

# %%
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# S3 prefix
#bucket = sagemaker_session.default_bucket()
bucket = 'credito-poc'
prefix = 'test1'

# %%
sagemaker.__version__
# Out:
# '2.0.0'

# %% [markdown]
# # Preprocessing data and training the model <a class="anchor" id="training"></a>
# ## Downloading dataset <a class="anchor" id="download_data"></a>
# SageMaker team has downloaded the dataset from UCI and uploaded to one of the S3 buckets in our account.

# %%
#!wget --directory-prefix=./abalone_data https://s3-us-west-2.amazonaws.com/sparkml-mleap/data/abalone/abalone.csv

# %% [markdown]
# ## Upload the data for training <a class="anchor" id="upload_data"></a>
#
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. We can use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
WORK_DIRECTORY = 'credito_data'

train_input = sagemaker_session.upload_data(
    path='{}/{}'.format(WORK_DIRECTORY, 'credito_limpo.csv'), 
    bucket=bucket,
    key_prefix='{}/{}'.format(prefix, 'train'))

# %%
train_input
# Out:
# 's3://credito-poc/test1/train/credito_limpo.csv'

# %% [markdown]
# bggg## Create a Scikit-learn script to train with <a class="anchor" id="create_sklearn_script"></a>
# To run Scikit-learn on Sagemaker `SKLearn` Estimator with a script as an entry point. The training script is very similar to a training script you might run outside of SageMaker, but you can access useful properties about the training environment through various environment variables, such as:
#
# * SM_MODEL_DIR: A string representing the path to the directory to write model artifacts to. These artifacts are uploaded to S3 for model hosting.
# * SM_OUTPUT_DIR: A string representing the filesystem path to write output artifacts to. Output artifacts may include checkpoints, graphs, and other files to save, not including model artifacts. These artifacts are compressed and uploaded to S3 to the same S3 prefix as the model artifacts.
#
# Supposing two input channels, 'train' and 'test', were used in the call to the Chainer estimator's fit() method, the following will be set, following the format SM_CHANNEL_[channel_name]:
#
# * SM_CHANNEL_TRAIN: A string representing the path to the directory containing data in the 'train' channel
# * SM_CHANNEL_TEST: Same as above, but for the 'test' channel.
#
# A typical training script loads data from the input channels, configures training with hyperparameters, trains a model, and saves a model to model_dir so that it can be hosted later. Hyperparameters are passed to your script as arguments and can be retrieved with an argparse.ArgumentParser instance. For example, the script run by this notebook
#
# ###  script usado é credito_featurizer.py

# %% [markdown]
# ## Create SageMaker Scikit Estimator <a class="anchor" id="create_sklearn_estimator"></a>
#
# To run our Scikit-learn training script on SageMaker, we construct a `sagemaker.sklearn.estimator.sklearn` estimator, which accepts several constructor arguments:
#
# * __entry_point__: The path to the Python script SageMaker runs for training and prediction.
# * __role__: Role ARN
# * __framework_version__: Scikit-learn version you want to use for executing your model training code.
# * __train_instance_type__ *(optional)*: The type of SageMaker instances for training. __Note__: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * __sagemaker_session__ *(optional)*: The session used to train on Sagemaker.
#
# To see the code for the SKLearn Estimator, see here: https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/sklearn

# %%
# !python credito_featurizer.py --train credito_data  --model .  --output-data-dir  .
# Out:
# Traceback (most recent call last):
#   File "credito_featurizer.py", line 17, in <module>
#     from sagemaker_containers.beta.framework import (
# ModuleNotFoundError: No module named 'sagemaker_containers'

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
script_path = 'credito_featurizer.py'

sklearn_preprocessor = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    #train_instance_type="ml.c4.xlarge",
    instance_type = "ml.m5.large",
    sagemaker_session=sagemaker_session)

# %%
train_input
# Out:
# 's3://credito-poc/test1/train/credito_limpo.csv'

# %%
sklearn_preprocessor.fit({'train': train_input})
# Out:
# 2021-02-19 11:27:21 Starting - Starting the training job...
# 2021-02-19 11:27:23 Starting - Launching requested ML instances......
# 2021-02-19 11:28:27 Starting - Preparing the instances for training......
# 2021-02-19 11:29:47 Downloading - Downloading input data
# 2021-02-19 11:29:47 Training - Downloading the training image...
# 2021-02-19 11:30:18 Uploading - Uploading generated training model.2021-02-19 11:30:13,306 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-02-19 11:30:13,315 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:30:13,331 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-02-19 11:30:13,622 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:30:16,669 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:30:16,681 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:30:16,691 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-02-19-11-27-20-768",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-02-19-11-27-20-768/source/sourcedir.tar.gz",
#     "module_name": "credito_featurizer",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "credito_featurizer.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=credito_featurizer.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=credito_featurizer
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-02-19-11-27-20-768/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-02-19-11-27-20-768","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-02-19-11-27-20-768/source/sourcedir.tar.gz","module_name":"credito_featurizer","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"credito_featurizer.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python credito_featurizer.py
#
#
# saved model!
# 2021-02-19 11:30:18,220 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-02-19 11:30:25 Completed - Training job completed
# Training seconds: 63
# Billable seconds: 63

# %% [markdown]
# ## Batch transform our training data <a class="anchor" id="preprocess_train_data"></a>
# Now that our proprocessor is properly fitted, let's go ahead and preprocess our training data. Let's use batch transform to directly preprocess the raw data and store right back into s3.

# %%
# Define a SKLearn Transformer from the trained SKLearn Estimator
transformer = sklearn_preprocessor.transformer(
    instance_count=1, 
    instance_type= 'ml.m5.xlarge',
    assemble_with = 'Line',
    accept = 'text/csv')

# %%
# Preprocess training input
transformer.transform(train_input, content_type="text/csv")
print("Waiting for transform job: " + transformer.latest_transform_job.job_name)
# Out:
# .........................2021-02-19 11:35:01,041 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:35:01,044 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:35:01,044 INFO - sagemaker-containers - nginx config:
# 2021-02-19 11:35:01,041 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:35:01,044 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:35:01,044 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021/02/19 11:35:01 [crit] 13#13: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Module credito_featurizer does not provide a setup.py.
# Generating setup.py
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Generating setup.cfg
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# 2021/02/19 11:35:01 [crit] 13#13: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021/02/19 11:35:01 [crit] 13#13: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Module credito_featurizer does not provide a setup.py.
# Generating setup.py
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Generating setup.cfg
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-02-19 11:35:01,176 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# 2021/02/19 11:35:01 [crit] 13#13: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Processing /opt/ml/code
# 2021/02/19 11:35:01 [crit] 13#13: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Building wheels for collected packages: credito-featurizer
#   Building wheel for credito-featurizer (setup.py): started
# 2021/02/19 11:35:01 [crit] 13#13: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for credito-featurizer (setup.py): finished with status 'done'
#   Created wheel for credito-featurizer: filename=credito_featurizer-1.0.0-py2.py3-none-any.whl size=8326 sha256=572b29bdcc9a75516e18a221c62192d0b87e1d24041c5a683ac042e893dc44e9
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-u9u_e1hr/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built credito-featurizer
# 2021/02/19 11:35:02 [crit] 13#13: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Installing collected packages: credito-featurizer
# Successfully installed credito-featurizer-1.0.0
# 2021/02/19 11:35:02 [crit] 13#13: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Processing /opt/ml/code
# 2021/02/19 11:35:01 [crit] 13#13: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Building wheels for collected packages: credito-featurizer
#   Building wheel for credito-featurizer (setup.py): started
# 2021/02/19 11:35:01 [crit] 13#13: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:01 [crit] 13#13: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:01 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for credito-featurizer (setup.py): finished with status 'done'
#   Created wheel for credito-featurizer: filename=credito_featurizer-1.0.0-py2.py3-none-any.whl size=8326 sha256=572b29bdcc9a75516e18a221c62192d0b87e1d24041c5a683ac042e893dc44e9
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-u9u_e1hr/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built credito-featurizer
# 2021/02/19 11:35:02 [crit] 13#13: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Installing collected packages: credito-featurizer
# Successfully installed credito-featurizer-1.0.0
# 2021/02/19 11:35:02 [crit] 13#13: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *33 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *35 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *37 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:03 [crit] 13#13: *39 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:03 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-02-19 11:35:03 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-02-19 11:35:03 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-02-19 11:35:03 +0000] [36] [INFO] Using worker: gevent
# [2021-02-19 11:35:03 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-02-19 11:35:03 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-02-19 11:35:03 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-02-19 11:35:03 +0000] [48] [INFO] Booting worker with pid: 48
# 2021/02/19 11:35:02 [crit] 13#13: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *33 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *35 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:02 [crit] 13#13: *37 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:02 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/02/19 11:35:03 [crit] 13#13: *39 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [19/Feb/2021:11:35:03 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-02-19 11:35:03 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-02-19 11:35:03 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-02-19 11:35:03 +0000] [36] [INFO] Using worker: gevent
# [2021-02-19 11:35:03 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-02-19 11:35:03 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-02-19 11:35:03 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-02-19 11:35:03 +0000] [48] [INFO] Booting worker with pid: 48
# 2021-02-19 11:35:03,806 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Feb/2021:11:35:04 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-02-19 11:35:04,347 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-02-19 11:35:03,806 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Feb/2021:11:35:04 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-02-19 11:35:04,347 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Feb/2021:11:35:04 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-02-19 11:35:04,860 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [19/Feb/2021:11:35:05 +0000] "POST /invocations HTTP/1.1" 200 362843 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Feb/2021:11:35:04 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-02-19 11:35:04,860 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [19/Feb/2021:11:35:05 +0000] "POST /invocations HTTP/1.1" 200 362843 "-" "Go-http-client/1.1"
# 2021-02-19T11:35:04.839:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# Waiting for transform job: sagemaker-scikit-learn-2021-02-19-11-31-03-887

# %%
#transformer.wait()
preprocessed_train = transformer.output_path

# %% [markdown]
# ## Fit a LinearLearner Model with the preprocessed data <a class="anchor" id="training_model"></a>
# Let's take the preprocessed training data and fit a LinearLearner Model. Sagemaker provides prebuilt algorithm containers that can be used with the Python SDK. The previous Scikit-learn job preprocessed the raw Titanic dataset into labeled, useable data that we can now use to fit a binary classifier Linear Learner model.
#
# For more on Linear Learner see: https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html

# %%
import boto3
from sagemaker.image_uris import retrieve
ll_image = retrieve('linear-learner', boto3.Session().region_name)

# %%
preprocessed_train
# Out:
# 's3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-02-19-11-31-03-887'

# %%
# import boto3
# import io
# s3 = boto3.client('s3')
# obj = s3.get_object(Bucket='sagemaker-us-east-2-785315722499', Key='sagemaker-scikit-learn-2021-02-18-21-28-39-475')
# df = pd.read_csv(io.BytesIO(obj['Body'].read()))

# %%
s3_ll_output_key_prefix = "ll_training_output"
s3_ll_output_location = 's3://{}/{}/{}/{}'.format(bucket, prefix, s3_ll_output_key_prefix, 'll_model')

ll_estimator = sagemaker.estimator.Estimator(
    ll_image,
    role, 
    instance_count=1, 
    instance_type='ml.m4.2xlarge',
    volume_size = 20,
    max_run = 3600,
    input_mode= 'File',
    output_path=s3_ll_output_location,
    sagemaker_session=sagemaker_session)

### incluir features depois do preprocessing - sem icluir a variavel y
### nosso caso no bucket preprocessed_train, o arquivo .out tem 47 colunas - sendo a primeira coluna y
ll_estimator.set_hyperparameters(feature_dim=46, predictor_type='binary_classifier', mini_batch_size=32)

ll_train_data = sagemaker.inputs.TrainingInput(
    preprocessed_train, 
    distribution='FullyReplicated',
    content_type='text/csv', 
    s3_data_type='S3Prefix')

data_channels = {'train': ll_train_data}
ll_estimator.fit(inputs=data_channels, logs=True)
# Out:
# 2021-02-19 11:41:06 Starting - Starting the training job...
# 2021-02-19 11:41:08 Starting - Launching requested ML instances.........
# 2021-02-19 11:42:41 Starting - Preparing the instances for training...
# 2021-02-19 11:43:29 Downloading - Downloading input data
# 2021-02-19 11:43:29 Training - Downloading the training image...
# 2021-02-19 11:43:58 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/19/2021 11:44:01 INFO 139884871800640] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/19/2021 11:44:01 INFO 139884871800640] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u
"Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093039}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5531793621278578, "sum": 0.5531793621278578, "min": 0.5531793621278578}}, "EndTime": 1613735057.093122, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093106}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5557040783666796, "sum": 0.5557040783666796, "min": 0.5557040783666796}}, "EndTime": 1613735057.093182, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093165}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5685904439418547, "sum": 0.5685904439418547, "min": 0.5685904439418547}}, "EndTime": 1613735057.093248, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.09323}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5918474562706486, "sum": 0.5918474562706486, "min": 0.5918474562706486}}, "EndTime": 1613735057.093314, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093297}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5685811263899649, "sum": 0.5685811263899649, "min": 0.5685811263899649}}, "EndTime": 1613735057.09338, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093362}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5918152265010341, "sum": 0.5918152265010341, "min": 0.5918152265010341}}, "EndTime": 1613735057.093445, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093428}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6091931962197826, "sum": 0.6091931962197826, "min": 0.6091931962197826}}, "EndTime": 1613735057.093509, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093492}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.610223606709511, "sum": 0.610223606709511, "min": 0.610223606709511}}, "EndTime": 1613735057.093576, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093559}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6092401271866213, "sum": 0.6092401271866213, "min": 0.6092401271866213}}, "EndTime": 1613735057.093639, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093622}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6101012662533791, "sum": 0.6101012662533791, "min": 0.6101012662533791}}, "EndTime": 1613735057.093705, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093688}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6195505290262161, "sum": 0.6195505290262161, "min": 0.6195505290262161}}, "EndTime": 1613735057.093764, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093748}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6343836601703398, "sum": 0.6343836601703398, "min": 0.6343836601703398}}, "EndTime": 1613735057.093827, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.09381}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6193472358488268, "sum": 0.6193472358488268, "min": 0.6193472358488268}}, "EndTime": 1613735057.093884, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093867}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6339869037751229, "sum": 0.6339869037751229, "min": 0.6339869037751229}}, "EndTime": 1613735057.093939, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735057.093923}
#
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.470784854504
# [02/19/2021 11:44:17 INFO 139884871800640] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.470784854504
# [02/19/2021 11:44:17 INFO 139884871800640] Saving model for epoch: 14
# [02/19/2021 11:44:17 INFO 139884871800640] Saved checkpoint to "/tmp/tmpresAJ5/mx-mod-0000.params"
# [02/19/2021 11:44:17 INFO 139884871800640] Early stop condition met. Stopping training.
# [02/19/2021 11:44:17 INFO 139884871800640] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 32, "sum": 32.0, "min": 32}, "Number of Batches Since Last Reset": {"count": 1, "max": 32, "sum": 32.0, "min": 32}, "Number of Records Since Last Reset": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Total Batches Seen": {"count": 1, "max": 513, "sum": 513.0, "min": 513}, "Total Records Seen": {"count": 1, "max": 16032, "sum": 16032.0, "min": 16032}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1613735057.100752, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613735056.148028}
#
# [02/19/2021 11:44:17 INFO 139884871800640] #throughput_metric: host=algo-1, train throughput=1049.47540042 records/second
# [02/19/2021 11:44:17 WARNING 139884871800640] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/19/2021 11:44:17 WARNING 139884871800640] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/19/2021 11:44:17 INFO 139884871800640] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.46634580516815183)
# [02/19/2021 11:44:17 INFO 139884871800640] #train_score (algo-1) : ('binary_classification_accuracy', 0.783)
# [02/19/2021 11:44:17 INFO 139884871800640] #train_score (algo-1) : ('binary_f_1.000', 0.5786407766990291)
# [02/19/2021 11:44:17 INFO 139884871800640] #train_score (algo-1) : ('precision', 0.6930232558139535)
# [02/19/2021 11:44:17 INFO 139884871800640] #train_score (algo-1) : ('recall', 0.49666666666666665)
# [02/19/2021 11:44:17 INFO 139884871800640] #train_score (algo-1) : ('roc_auc_score', 0.8179238095238096)
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.466345805168
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.783
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.578640776699
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, train precision <score>=0.693023255814
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, train recall <score>=0.496666666667
# [02/19/2021 11:44:17 INFO 139884871800640] #quality_metric: host=algo-1, train roc_auc_score <score>=0.817923809524
# [02/19/2021 11:44:17 INFO 139884871800640] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [02/19/2021 11:44:17 INFO 139884871800640] Saved checkpoint to "/tmp/tmpEr2WmH/mx-mod-0000.params"
# [02/19/2021 11:44:17 INFO 139884871800640] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 16090.646028518677, "sum": 16090.646028518677, "min": 16090.646028518677}, "finalize.time": {"count": 1, "max": 401.5920162200928, "sum": 401.5920162200928, "min": 401.5920162200928}, "initialize.time": {"count": 1, "max": 333.7359428405762, "sum": 333.7359428405762, "min": 333.7359428405762}, "check_early_stopping.time": {"count": 15, "max": 1.3089179992675781, "sum": 10.350465774536133, "min": 0.1862049102783203}, "setuptime": {"count": 1, "max": 26.287078857421875, "sum": 26.287078857421875, "min": 26.287078857421875}, "update.time": {"count": 15, "max": 1258.7780952453613, "sum": 15104.913234710693, "min": 917.3669815063477}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1613735057.507941, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613735041.619238}
#
#
# 2021-02-19 11:44:26 Uploading - Uploading generated training model
# 2021-02-19 11:44:26 Completed - Training job completed
# Training seconds: 71
# Billable seconds: 71

# %% [markdown]
# # Serial Inference Pipeline with Scikit preprocessor and Linear Learner <a class="anchor" id="serial_inference"></a>

# %% [markdown]
# ## Set up the inference pipeline <a class="anchor" id="pipeline_setup"></a>
# Setting up a Machine Learning pipeline can be done with the Pipeline Model. This sets up a list of models in a single endpoint; in this example, we configure our pipeline model with the fitted Scikit-learn inference model and the fitted Linear Learner model. Deploying the model follows the same ```deploy``` pattern in the SDK.

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = 'inference-pipeline-' + timestamp_prefix
endpoint_name = 'inference-pipeline-ep-' + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, 
    role=role, 
    models=[
        scikit_learn_inferencee_model ,
        linear_learner_model])

sm_model.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge', endpoint_name=endpoint_name)
# Out:
# -----------------!

# %% [markdown]
# ## DEPLOY ENDPOINT FROM S3
# Neste caso o modelo ja foi produzido e uma cópia encontra-se em S3
# Para economia de custos, devemos baixar o endpoint sempre que nao estáem uso, e levantar com esta rotina

# %%
from sagemaker.sklearn.model import SKLearnModel
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()
# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()
script_path = 'credito_featurizer.py'

# %%
###  retrieve the preprocessing model
modelo = 's3://sagemaker-us-east-2-785315722499/sagemaker-scikit-learn-2021-02-19-11-27-20-768/output/model.tar.gz'
FRAMEWORK_VERSION = "0.23-1"    
    
scikit_learn_inferencee_model = SKLearnModel(model_data=modelo,
                             role=role,
                             entry_point=script_path,
                             sagemaker_session=sagemaker_session,
                             framework_version=FRAMEWORK_VERSION)




#mau_model.deploy(instance_type="ml.c4.xlarge", initial_instance_count=1,endpoint_name='credito1')

# %%
# retrieve the linear model
modelo = 's3://credito-poc/test1/ll_training_output/ll_model/linear-learner-2021-02-19-11-41-06-019/output/model.tar.gz'
FRAMEWORK_VERSION = "0.23-1"    
    
linear_learner_model =     SKLearnModel(model_data=modelo,
                             role=role,
                             entry_point=script_path,
                             sagemaker_session=sagemaker_session,
                             framework_version=FRAMEWORK_VERSION)

# %%
# make pipeline fromm the two previous models

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

#scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
#linear_learner_model = ll_estimator.create_model()

model_name = 'inference-pipeline-' + timestamp_prefix
endpoint_name = 'inference-pipeline-ep-' + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, 
    role=role, 
    models=[
        scikit_learn_inferencee_model ,
        linear_learner_model])

sm_model.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge', endpoint_name=endpoint_name)
# Out:
# -

# %% [markdown]
# ## Make a request to our pipeline endpoint <a class="anchor" id="pipeline_inference_request"></a>
#
# Here we just grab the first line from the test data (you'll notice that the inference python script is very particular about the ordering of the inference request data). The ```ContentType``` field configures the first container, while the ```Accept``` field configures the last container. You can also specify each container's ```Accept``` and ```ContentType``` values using environment variables.
#
# We make our request with the payload in ```'text/csv'``` format, since that is what our script currently supports. If other formats need to be supported, this would have to be added to the ```output_fn()``` method in our entry point. Note that we set the ```Accept``` to ```application/json```, since Linear Learner does not support ```text/csv``` ```Accept```. The prediction output in this case is trying to guess the number of rings the abalone specimen would have given its other physical features; the actual number of rings is 10.

# %%
print(endpoint_name)
# endpoint_name = inference-pipeline-ep-2021-02-19-11-47-0
# Out:
# inference-pipeline-ep-2021-02-19-11-47-06

# %%
endpoint_name = 'inference-pipeline-ep-2021-02-19-15-09-17'
#endpoint_name = 'inference-pipeline-ep-2021-02-19-11-47-06'

# %%
###  Prediction using Python SDK

import sagemaker
from sagemaker import get_execution_role

from sagemaker.predictor import Predictor
#from sagemaker.predictor import predict
from sagemaker.serializers import CSVSerializer
sagemaker_session = sagemaker.Session()
#endpoint_name = 'inference-pipeline-ep-2021-02-15-13-10-44'
payload = '0,0,0,operario,sem conta,2,1,1,muito_alta,2,1500,Nao,2,6,muito pobre,imovel,carro novo,proprio,2'

predictor = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=CSVSerializer())

print(predictor.predict(payload))
# Out:
# b'{"predictions": [{"score": 0.025737501680850983, "predicted_label": 0}]}'

# %%
##  Prediction using boto3 - like in Lambda
import json
runtime = boto3.client('runtime.sagemaker')

# Send CSV text via InvokeEndpoint API
response = runtime.invoke_endpoint(EndpointName=endpoint_name, ContentType='text/csv', Body=payload)
# Unpack response
result = json.loads(response['Body'].read().decode())
result
# Out:
# {'predictions': [{'score': 0.025737501680850983, 'predicted_label': 0}]}

# %% [markdown]
# ## Delete Endpoint <a class="anchor" id="delete_endpoint"></a>
# Once we are finished with the endpoint, we clean up the resources!

# %%
sm_client = sagemaker_session.boto_session.client('sagemaker')
sm_client.delete_endpoint(EndpointName=endpoint_name)
